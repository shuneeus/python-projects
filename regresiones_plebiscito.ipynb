# %%
import pandas as pd
import janitor 

data = "/home/sebastian/Insync/lshuneeus@uc.cl/Google Drive/curso analisis datos politicos 2020/ayudantias shuneeus/bases_ayudantias/bd_plebiscito.xlsx"

plebiscito = pd.read_excel(data, index_col = 1.clean_names().dropna(how='all')

plebiscito
# Out:
#                      idcomuna  total_mesas  total_electores  total_votacion  \
# Comuna
# ALHUE                 13502.0         21.0           6004.0          2640.0
# BUIN                  13402.0        251.0          73511.0         40566.0
# CALERA DE TANGO       13403.0         65.0          22016.0         12750.0
# CERRILLOS             13102.0        205.0          67845.0         37316.0
# CERRO NAVIA           13103.0        350.0         116544.0         64105.0
# COLINA                13301.0        258.0          87987.0         49450.0
# CONCHALI              13104.0        387.0         119859.0         65349.0
# CURACAVI              13503.0         75.0          25834.0         14789.0
# EL BOSQUE             13105.0        409.0         138923.0         75827.0
# EL MONTE              13602.0         80.0          27418.0         15075.0
# ESTACION CENTRAL      13106.0        396.0         127362.0         62960.0
# ...

# %%
plebiscito["apruebo_porcentaje"] = plebiscito["apruebo"] / plebiscito["total_votacion"]

# %%
print(plebiscito.dtypes)
# Out:
# idcomuna                     float64
# total_mesas                  float64
# total_electores              float64
# total_votacion               float64
# apruebo                      float64
# rechazo                      float64
# personas_pobreza_ingresos    float64
# porc_pobreza_ingresos        float64
# ingreso_promedio             float64
# ingresos_municipales_pc       object
# apruebo_porcentaje           float64
# dtype: object

# %%
plebiscito.describe()
# Out:
#            idcomuna  total_mesas  total_electores  total_votacion  \
# count     52.000000    52.000000        52.000000       52.000000
# mean   13238.076923   337.673077    112296.096154    63561.192308
# std      178.051309   274.266631     91530.134319    52827.130751
# min    13101.000000    21.000000      6004.000000     2640.000000
# 25%    13113.750000   170.250000     57485.000000    33589.000000
# 50%    13126.500000   276.500000     90727.500000    53190.000000
# 75%    13401.250000   403.500000    138422.750000    73034.000000
# max    13605.000000  1245.000000    398965.000000   243011.000000
#
#              apruebo       rechazo  personas_pobreza_ingresos  \
# count      52.000000     52.000000                  52.000000
# mean    50466.903846  12793.307692                7447.211538
# std     43811.775006  15046.243246               10796.269006
# min      2323.000000    309.000000                  99.000000
# ...

# %%
plebiscito.plot(x='apruebo_porcentaje', y='porc_pobreza_ingresos', style='o')
plt.title('Approve against poverty')
plt.xlabel('Approve')
plt.ylabel('Poverty')
plt.show()

# %%
# https://www.statsmodels.org/devel/example_formulas.html

import statsmodels.api as sm
import statsmodels.formula.api as smf

linear_model = smf.ols(formula ='apruebo_porcentaje ~ porc_pobreza_ingresos + ingreso_promedio', data=plebiscito)

result = linear_model.fit()

print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     apruebo_porcentaje   R-squared:                       0.739
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     69.43
# Date:                Fri, 08 Jan 2021   Prob (F-statistic):           5.02e-15
# Time:                        21:38:37   Log-Likelihood:                 73.165
# No. Observations:                  52   AIC:                            -140.3
# Df Residuals:                      49   BIC:                            -134.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 1.1242      0.054     20.776      0.000       1.015       1.233
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(plebiscito.ingreso_promedio, plebiscito.apruebo_porcentaje)
# Out:
# /home/sebastian/anaconda3/envs/prueba1/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ingreso_promedio', ylabel='apruebo_porcentaje'>
